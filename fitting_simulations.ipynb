# %%
import numpy as np
import pandas as pd
import hssm
import arviz as az
import sqlite3
from datetime import datetime

# %%
from hssm_utils import get_fitted_participants, write_summary_to_sql
from hssm_models import fit_hssm_mod_th_single, fit_hssm_mod_v_single
from hssm_models import fit_hssm_participant as fit_hssm_pure
from hssm_models import run_sequential_fits

# %%
with sqlite3.connect('hssm_sims.sqlite') as conn:
    df_ddm_mod_th = pd.read_sql("SELECT * FROM th_ddm;", conn)
    th_df = pd.DataFrame(df_ddm_mod_th)

    df_ddm_mod_v = pd.read_sql("SELECT * FROM v_ddm;", conn)
    v_df = pd.DataFrame(df_ddm_mod_v)

    df_ddm_pure = pd.read_sql("SELECT * FROM pure_ddm;", conn)
    pure_df = pd.DataFrame(df_ddm_pure)

# %%
th_df
# Out:
#               rt  response participant_id  X
# 0       1.576992      -1.0            935  0
# 1       1.232995       1.0            935  0
# 2       1.326993      -1.0            935  0
# 3       2.398030      -1.0            935  0
# 4       1.820003       1.0            935  0
# ...          ...       ...            ... ..
# 102895  2.024017       1.0           1111  0
# 102896  1.167994       1.0           1111  1
# 102897  0.842999       1.0           1111  0
# 102898  1.302993      -1.0           1111  1
# 102899  2.006016       1.0           1111  1
#
# [102900 rows x 4 columns]

# %%
print("starting TH fits")
run_sequential_fits(th_df, 'participant_id','hssm_sim_fits_th.sqlite', predictor='X', max_participants=20, model_name='ddm_mod_th')
print("starting V fits")
run_sequential_fits(th_df, 'participant_id','hssm_sim_fits_th.sqlite', predictor='X', max_participants=20, model_name='ddm_mod_v')
print("starting PURE fits")
run_sequential_fits(th_df, 'participant_id','hssm_sim_fits_th.sqlite', predictor='X', max_participants=20, model_name='ddm_pure')
# Out:
# starting TH fits
# starting V fits
# starting PURE fits

# %%
run_sequential_fits(v_df, 'participant_id','hssm_sim_fits_v.sqlite', predictor='X', max_participants=20, model_name='ddm_mod_th')
run_sequential_fits(v_df, 'participant_id','hssm_sim_fits_v.sqlite', predictor='X', max_participants=20, model_name='ddm_mod_v')
run_sequential_fits(v_df, 'participant_id','hssm_sim_fits_v.sqlite', predictor='X', max_participants=20, model_name='ddm_pure')

# %%
run_sequential_fits(pure_df, 'participant_id','hssm_sim_fits_pure.sqlite', predictor='X', max_participants=10, model_name='ddm_mod_th')
run_sequential_fits(pure_df, 'participant_id','hssm_sim_fits_pure.sqlite', predictor='X', max_participants=10, model_name='ddm_mod_v')
run_sequential_fits(pure_df, 'participant_id','hssm_sim_fits_pure.sqlite', predictor='X', max_participants=10, model_name='ddm_pure')
# Out:
# Only 300 samples in chain.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: local_pow_specialize
# ERROR (pytensor.graph.rewriting.basic): node: Pow(Add.0, [[2]])
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/Users/javierrojas/Library/Python/3.9/lib/python/site-packages/pytensor/graph/rewriting/basic.py", line 1914, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#   File "/Users/javierrojas/Library/Python/3.9/lib/python/site-packages/pytensor/graph/rewriting/basic.py", line 1074, in transform
#     return self.fn(fgraph, node)
#   File "/Users/javierrojas/Library/Python/3.9/lib/python/site-packages/pytensor/tensor/rewriting/math.py", line 2075, in local_pow_specialize
#     assert rval[0].type == node.outputs[0].type, (rval, node.outputs)
# AssertionError: ([Sqr.0], [Pow.0])
# ❌ Failed participant 807: ([Sqr.0], [Pow.0])
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:20&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 20 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.371  0.085   0.213    0.527      0.004    0.003     573.0
# 1    a_Intercept  0.863  0.034   0.800    0.932      0.001    0.001     658.0
# 2            a_X -0.023  0.043  -0.102    0.056      0.002    0.002     666.0
# 3              z  0.544  0.020   0.512    0.585      0.001    0.001     545.0
# 4              t  0.765  0.015   0.736    0.792      0.001    0.000     590.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  0.863  0.034   0.800    0.932      0.001    0.001     658.0
# 301       a[296]  0.840  0.035   0.784    0.913      0.001    0.001     597.0
# 302       a[297]  0.863  0.034   0.800    0.932      0.001    0.001     658.0
# 303       a[298]  0.840  0.035   0.784    0.913      0.001    0.001     597.0
# 304       a[299]  0.840  0.035   0.784    0.913      0.001    0.001     597.0
#
#      ess_tail  r_hat participant_id
# 0       516.0   1.01            999
# 1       627.0   1.00            999
# 2       567.0   1.00            999
# 3       643.0   1.00            999
# 4       489.0   1.01            999
# ..        ...    ...            ...
# 300     627.0   1.00            999
# 301     530.0   1.01            999
# 302     627.0   1.00            999
# 303     530.0   1.01            999
# 304     530.0   1.01            999
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:15&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 15 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.280  0.038   0.209    0.351      0.002    0.001     494.0
# 1    a_Intercept  2.506  0.101   2.308    2.689      0.004    0.003     716.0
# 2            a_X  0.043  0.118  -0.174    0.256      0.005    0.004     665.0
# 3              z  0.583  0.030   0.527    0.638      0.002    0.001     391.0
# 4              t  0.472  0.121   0.214    0.670      0.006    0.004     421.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  2.506  0.101   2.308    2.689      0.004    0.003     716.0
# 301       a[296]  2.549  0.105   2.371    2.752      0.004    0.003     637.0
# 302       a[297]  2.549  0.105   2.371    2.752      0.004    0.003     637.0
# 303       a[298]  2.506  0.101   2.308    2.689      0.004    0.003     716.0
# 304       a[299]  2.506  0.101   2.308    2.689      0.004    0.003     716.0
#
#      ess_tail  r_hat participant_id
# 0       524.0   1.01           1089
# 1       453.0   1.00           1089
# 2       506.0   1.00           1089
# 3       449.0   1.01           1089
# 4       289.0   1.00           1089
# ..        ...    ...            ...
# 300     453.0   1.00           1089
# 301     420.0   1.00           1089
# 302     420.0   1.00           1089
# 303     453.0   1.00           1089
# 304     453.0   1.00           1089
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:13&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 14 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.816  0.091   0.671    0.996      0.005    0.003     372.0
# 1    a_Intercept  1.185  0.055   1.082    1.290      0.003    0.002     304.0
# 2            a_X -0.098  0.063  -0.201    0.027      0.003    0.002     501.0
# 3              z  0.524  0.031   0.467    0.581      0.002    0.001     311.0
# 4              t  0.579  0.026   0.531    0.623      0.001    0.001     316.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  1.185  0.055   1.082    1.290      0.003    0.002     304.0
# 301       a[296]  1.185  0.055   1.082    1.290      0.003    0.002     304.0
# 302       a[297]  1.185  0.055   1.082    1.290      0.003    0.002     304.0
# 303       a[298]  1.087  0.055   0.996    1.200      0.002    0.002     619.0
# 304       a[299]  1.087  0.055   0.996    1.200      0.002    0.002     619.0
#
#      ess_tail  r_hat participant_id
# 0       492.0   1.01            715
# 1       230.0   1.00            715
# 2       477.0   1.00            715
# 3       354.0   1.01            715
# 4       455.0   1.01            715
# ..        ...    ...            ...
# 300     230.0   1.00            715
# 301     230.0   1.00            715
# 302     230.0   1.00            715
# 303     619.0   1.00            715
# 304     619.0   1.00            715
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:11&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 12 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.273  0.070   0.153    0.421      0.003    0.002     577.0
# 1    a_Intercept  1.050  0.040   0.974    1.123      0.002    0.001     603.0
# 2            a_X -0.047  0.050  -0.136    0.048      0.002    0.001     748.0
# 3              z  0.508  0.021   0.468    0.548      0.001    0.001     475.0
# 4              t  0.739  0.017   0.705    0.769      0.001    0.001     503.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  1.003  0.038   0.936    1.071      0.001    0.001     645.0
# 301       a[296]  1.003  0.038   0.936    1.071      0.001    0.001     645.0
# 302       a[297]  1.050  0.040   0.974    1.123      0.002    0.001     603.0
# 303       a[298]  1.003  0.038   0.936    1.071      0.001    0.001     645.0
# 304       a[299]  1.003  0.038   0.936    1.071      0.001    0.001     645.0
#
#      ess_tail  r_hat participant_id
# 0       534.0   1.01            721
# 1       560.0   1.01            721
# 2       616.0   1.00            721
# 3       639.0   1.01            721
# 4       619.0   1.00            721
# ..        ...    ...            ...
# 300     737.0   1.00            721
# 301     737.0   1.00            721
# 302     560.0   1.01            721
# 303     737.0   1.00            721
# 304     737.0   1.00            721
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:13&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 14 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.877  0.095   0.705    1.058      0.004    0.003     579.0
# 1    a_Intercept  0.876  0.035   0.818    0.951      0.002    0.001     526.0
# 2            a_X -0.025  0.040  -0.102    0.045      0.002    0.001     700.0
# 3              z  0.448  0.022   0.409    0.488      0.001    0.001     584.0
# 4              t  0.696  0.013   0.669    0.720      0.001    0.000     562.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  0.876  0.035   0.818    0.951      0.002    0.001     526.0
# 301       a[296]  0.876  0.035   0.818    0.951      0.002    0.001     526.0
# 302       a[297]  0.851  0.034   0.794    0.918      0.001    0.001     564.0
# 303       a[298]  0.851  0.034   0.794    0.918      0.001    0.001     564.0
# 304       a[299]  0.876  0.035   0.818    0.951      0.002    0.001     526.0
#
#      ess_tail  r_hat participant_id
# 0       369.0   1.00            725
# 1       478.0   1.00            725
# 2       640.0   1.00            725
# 3       548.0   1.00            725
# 4       479.0   1.01            725
# ..        ...    ...            ...
# 300     478.0   1.00            725
# 301     478.0   1.00            725
# 302     570.0   1.01            725
# 303     570.0   1.01            725
# 304     478.0   1.00            725
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:12&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 13 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.387  0.064   0.269    0.504      0.003    0.002     594.0
# 1    a_Intercept  1.395  0.056   1.300    1.514      0.002    0.001     739.0
# 2            a_X -0.033  0.068  -0.159    0.097      0.002    0.002     785.0
# 3              z  0.557  0.024   0.516    0.602      0.001    0.001     509.0
# 4              t  0.885  0.034   0.820    0.951      0.002    0.001     516.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  1.362  0.058   1.262    1.471      0.002    0.002     764.0
# 301       a[296]  1.362  0.058   1.262    1.471      0.002    0.002     764.0
# 302       a[297]  1.395  0.056   1.300    1.514      0.002    0.001     739.0
# 303       a[298]  1.362  0.058   1.262    1.471      0.002    0.002     764.0
# 304       a[299]  1.395  0.056   1.300    1.514      0.002    0.001     739.0
#
#      ess_tail  r_hat participant_id
# 0       533.0    1.0            729
# 1       579.0    1.0            729
# 2       687.0    1.0            729
# 3       618.0    1.0            729
# 4       333.0    1.0            729
# ..        ...    ...            ...
# 300     514.0    1.0            729
# 301     514.0    1.0            729
# 302     579.0    1.0            729
# 303     514.0    1.0            729
# 304     579.0    1.0            729
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:14&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 15 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.462  0.056   0.361    0.563      0.003    0.002     458.0
# 1    a_Intercept  1.566  0.066   1.453    1.692      0.003    0.002     575.0
# 2            a_X  0.032  0.078  -0.129    0.168      0.003    0.002     602.0
# 3              z  0.528  0.025   0.480    0.571      0.001    0.001     356.0
# 4              t  2.254  0.047   2.166    2.335      0.003    0.002     351.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  1.598  0.071   1.467    1.723      0.003    0.002     513.0
# 301       a[296]  1.566  0.066   1.453    1.692      0.003    0.002     575.0
# 302       a[297]  1.566  0.066   1.453    1.692      0.003    0.002     575.0
# 303       a[298]  1.566  0.066   1.453    1.692      0.003    0.002     575.0
# 304       a[299]  1.598  0.071   1.467    1.723      0.003    0.002     513.0
#
#      ess_tail  r_hat participant_id
# 0       476.0   1.00            740
# 1       662.0   1.00            740
# 2       601.0   1.00            740
# 3       452.0   1.01            740
# 4       428.0   1.01            740
# ..        ...    ...            ...
# 300     508.0   1.00            740
# 301     662.0   1.00            740
# 302     662.0   1.00            740
# 303     662.0   1.00            740
# 304     508.0   1.00            740
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:12&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 13 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.152  0.053   0.039    0.238      0.002    0.002     607.0
# 1    a_Intercept  1.452  0.057   1.348    1.561      0.002    0.001     746.0
# 2            a_X -0.040  0.065  -0.166    0.080      0.002    0.002     811.0
# 3              z  0.575  0.022   0.533    0.614      0.001    0.001     549.0
# 4              t  1.769  0.032   1.713    1.830      0.001    0.001     604.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  1.412  0.053   1.307    1.508      0.002    0.001     814.0
# 301       a[296]  1.452  0.057   1.348    1.561      0.002    0.001     746.0
# 302       a[297]  1.412  0.053   1.307    1.508      0.002    0.001     814.0
# 303       a[298]  1.412  0.053   1.307    1.508      0.002    0.001     814.0
# 304       a[299]  1.452  0.057   1.348    1.561      0.002    0.001     746.0
#
#      ess_tail  r_hat participant_id
# 0       716.0   1.00            835
# 1       645.0   1.00            835
# 2       669.0   1.01            835
# 3       668.0   1.00            835
# 4       602.0   1.00            835
# ..        ...    ...            ...
# 300     543.0   1.00            835
# 301     645.0   1.00            835
# 302     543.0   1.00            835
# 303     543.0   1.00            835
# 304     645.0   1.00            835
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:14&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 15 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.603  0.074   0.464    0.740      0.003    0.002     459.0
# 1    a_Intercept  1.229  0.052   1.140    1.336      0.002    0.002     539.0
# 2            a_X -0.013  0.063  -0.137    0.095      0.002    0.002     669.0
# 3              z  0.543  0.027   0.497    0.599      0.001    0.001     426.0
# 4              t  1.219  0.026   1.170    1.264      0.002    0.001     330.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  1.229  0.052   1.140    1.336      0.002    0.002     539.0
# 301       a[296]  1.229  0.052   1.140    1.336      0.002    0.002     539.0
# 302       a[297]  1.217  0.053   1.111    1.309      0.002    0.002     592.0
# 303       a[298]  1.229  0.052   1.140    1.336      0.002    0.002     539.0
# 304       a[299]  1.229  0.052   1.140    1.336      0.002    0.002     539.0
#
#      ess_tail  r_hat participant_id
# 0       590.0   1.00            920
# 1       549.0   1.00            920
# 2       516.0   1.02            920
# 3       484.0   1.01            920
# 4       372.0   1.01            920
# ..        ...    ...            ...
# 300     549.0   1.00            920
# 301     549.0   1.00            920
# 302     517.0   1.01            920
# 303     549.0   1.00            920
# 304     549.0   1.00            920
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, t, v_Intercept, a_Intercept, a_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:16&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 17 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#            param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0    v_Intercept  0.665  0.079   0.523    0.827      0.004    0.003     358.0
# 1    a_Intercept  1.331  0.067   1.204    1.456      0.003    0.002     590.0
# 2            a_X  0.017  0.074  -0.129    0.152      0.003    0.002     660.0
# 3              z  0.625  0.027   0.569    0.674      0.001    0.001     408.0
# 4              t  1.035  0.025   0.984    1.081      0.001    0.001     489.0
# ..           ...    ...    ...     ...      ...        ...      ...       ...
# 300       a[295]  1.348  0.066   1.218    1.464      0.003    0.002     642.0
# 301       a[296]  1.348  0.066   1.218    1.464      0.003    0.002     642.0
# 302       a[297]  1.348  0.066   1.218    1.464      0.003    0.002     642.0
# 303       a[298]  1.348  0.066   1.218    1.464      0.003    0.002     642.0
# 304       a[299]  1.331  0.067   1.204    1.456      0.003    0.002     590.0
#
#      ess_tail  r_hat participant_id
# 0       369.0   1.01            976
# 1       577.0   1.00            976
# 2       474.0   1.00            976
# 3       534.0   1.01            976
# 4       467.0   1.01            976
# ..        ...    ...            ...
# 300     488.0   1.00            976
# 301     488.0   1.00            976
# 302     488.0   1.00            976
# 303     488.0   1.00            976
# 304     577.0   1.00            976
#
# [305 rows x 11 columns]
# writing
# Only 300 samples in chain.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: local_pow_specialize
# ERROR (pytensor.graph.rewriting.basic): node: Pow(Add.0, [[2]])
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/Users/javierrojas/Library/Python/3.9/lib/python/site-packages/pytensor/graph/rewriting/basic.py", line 1914, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#   File "/Users/javierrojas/Library/Python/3.9/lib/python/site-packages/pytensor/graph/rewriting/basic.py", line 1074, in transform
#     return self.fn(fgraph, node)
#   File "/Users/javierrojas/Library/Python/3.9/lib/python/site-packages/pytensor/tensor/rewriting/math.py", line 2075, in local_pow_specialize
#     assert rval[0].type == node.outputs[0].type, (rval, node.outputs)
# AssertionError: ([Sqr.0], [Pow.0])
# ❌ Failed participant 807: ([Sqr.0], [Pow.0])
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v_Intercept, v_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:13&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 13 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# <class 'arviz.data.inference_data.InferenceData'>
# <class 'pandas.core.frame.DataFrame'>
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.421  0.097   0.241    0.600      0.004    0.003     628.0
# 1          v_X -0.047  0.103  -0.243    0.135      0.004    0.003     663.0
# 2            z  0.559  0.022   0.518    0.601      0.001    0.001     646.0
# 3            a  0.856  0.026   0.814    0.911      0.001    0.001     767.0
# 4            t  0.638  0.011   0.617    0.659      0.000    0.000     662.0
#
#    ess_tail  r_hat participant_id
# 0     715.0   1.00            864
# 1     604.0   1.00            864
# 2     600.0   1.01            864
# 3     588.0   1.00            864
# 4     404.0   1.00            864
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.421  0.097   0.241    0.600      0.004    0.003     628.0
# 1          v_X -0.047  0.103  -0.243    0.135      0.004    0.003     663.0
# 2            z  0.559  0.022   0.518    0.601      0.001    0.001     646.0
# 3            a  0.856  0.026   0.814    0.911      0.001    0.001     767.0
# 4            t  0.638  0.011   0.617    0.659      0.000    0.000     662.0
#
#    ess_tail  r_hat participant_id
# 0     715.0   1.00            864
# 1     604.0   1.00            864
# 2     600.0   1.01            864
# 3     588.0   1.00            864
# 4     404.0   1.00            864
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v_Intercept, v_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:16&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 17 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# <class 'arviz.data.inference_data.InferenceData'>
# <class 'pandas.core.frame.DataFrame'>
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.686  0.123   0.432    0.889      0.005    0.004     580.0
# 1          v_X -0.070  0.120  -0.278    0.165      0.005    0.004     643.0
# 2            z  0.553  0.022   0.508    0.591      0.001    0.001     469.0
# 3            a  0.715  0.023   0.675    0.758      0.001    0.001     615.0
# 4            t  0.605  0.008   0.591    0.620      0.000    0.000     479.0
#
#    ess_tail  r_hat participant_id
# 0     584.0   1.01            929
# 1     580.0   1.01            929
# 2     514.0   1.01            929
# 3     596.0   1.00            929
# 4     457.0   1.01            929
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.686  0.123   0.432    0.889      0.005    0.004     580.0
# 1          v_X -0.070  0.120  -0.278    0.165      0.005    0.004     643.0
# 2            z  0.553  0.022   0.508    0.591      0.001    0.001     469.0
# 3            a  0.715  0.023   0.675    0.758      0.001    0.001     615.0
# 4            t  0.605  0.008   0.591    0.620      0.000    0.000     479.0
#
#    ess_tail  r_hat participant_id
# 0     584.0   1.01            929
# 1     580.0   1.01            929
# 2     514.0   1.01            929
# 3     596.0   1.00            929
# 4     457.0   1.01            929
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v_Intercept, v_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:14&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 15 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# <class 'arviz.data.inference_data.InferenceData'>
# <class 'pandas.core.frame.DataFrame'>
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.549  0.070   0.425    0.679      0.003    0.002     434.0
# 1          v_X -0.066  0.076  -0.220    0.074      0.003    0.003     496.0
# 2            z  0.545  0.025   0.497    0.589      0.001    0.001     475.0
# 3            a  1.804  0.075   1.663    1.940      0.003    0.002     480.0
# 4            t  1.090  0.061   0.973    1.198      0.003    0.002     389.0
#
#    ess_tail  r_hat participant_id
# 0     435.0   1.00            949
# 1     357.0   1.00            949
# 2     573.0   1.00            949
# 3     394.0   1.00            949
# 4     659.0   1.01            949
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.549  0.070   0.425    0.679      0.003    0.002     434.0
# 1          v_X -0.066  0.076  -0.220    0.074      0.003    0.003     496.0
# 2            z  0.545  0.025   0.497    0.589      0.001    0.001     475.0
# 3            a  1.804  0.075   1.663    1.940      0.003    0.002     480.0
# 4            t  1.090  0.061   0.973    1.198      0.003    0.002     389.0
#
#    ess_tail  r_hat participant_id
# 0     435.0   1.00            949
# 1     357.0   1.00            949
# 2     573.0   1.00            949
# 3     394.0   1.00            949
# 4     659.0   1.01            949
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v_Intercept, v_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:17&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 18 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# <class 'arviz.data.inference_data.InferenceData'>
# <class 'pandas.core.frame.DataFrame'>
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.391  0.055   0.291    0.497      0.002    0.002     508.0
# 1          v_X  0.052  0.065  -0.073    0.174      0.003    0.002     608.0
# 2            z  0.553  0.034   0.486    0.615      0.002    0.001     352.0
# 3            a  2.314  0.094   2.143    2.479      0.004    0.003     532.0
# 4            t  0.912  0.112   0.695    1.114      0.005    0.004     416.0
#
#    ess_tail  r_hat participant_id
# 0     536.0    1.0            967
# 1     504.0    1.0            967
# 2     618.0    1.0            967
# 3     495.0    1.0            967
# 4     487.0    1.0            967
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.391  0.055   0.291    0.497      0.002    0.002     508.0
# 1          v_X  0.052  0.065  -0.073    0.174      0.003    0.002     608.0
# 2            z  0.553  0.034   0.486    0.615      0.002    0.001     352.0
# 3            a  2.314  0.094   2.143    2.479      0.004    0.003     532.0
# 4            t  0.912  0.112   0.695    1.114      0.005    0.004     416.0
#
#    ess_tail  r_hat participant_id
# 0     536.0    1.0            967
# 1     504.0    1.0            967
# 2     618.0    1.0            967
# 3     495.0    1.0            967
# 4     487.0    1.0            967
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v_Intercept, v_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:13&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 13 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# <class 'arviz.data.inference_data.InferenceData'>
# <class 'pandas.core.frame.DataFrame'>
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.391  0.083   0.224    0.542      0.003    0.002     657.0
# 1          v_X -0.064  0.094  -0.223    0.125      0.003    0.003     752.0
# 2            z  0.515  0.022   0.475    0.558      0.001    0.001     583.0
# 3            a  1.117  0.034   1.056    1.176      0.001    0.001     638.0
# 4            t  0.668  0.024   0.622    0.713      0.001    0.001     537.0
#
#    ess_tail  r_hat participant_id
# 0     643.0   1.00           1015
# 1     691.0   1.00           1015
# 2     582.0   1.00           1015
# 3     736.0   1.01           1015
# 4     635.0   1.01           1015
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.391  0.083   0.224    0.542      0.003    0.002     657.0
# 1          v_X -0.064  0.094  -0.223    0.125      0.003    0.003     752.0
# 2            z  0.515  0.022   0.475    0.558      0.001    0.001     583.0
# 3            a  1.117  0.034   1.056    1.176      0.001    0.001     638.0
# 4            t  0.668  0.024   0.622    0.713      0.001    0.001     537.0
#
#    ess_tail  r_hat participant_id
# 0     643.0   1.00           1015
# 1     691.0   1.00           1015
# 2     582.0   1.00           1015
# 3     736.0   1.01           1015
# 4     635.0   1.01           1015
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v_Intercept, v_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:15&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 15 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# <class 'arviz.data.inference_data.InferenceData'>
# <class 'pandas.core.frame.DataFrame'>
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.127  0.076  -0.025    0.253      0.004    0.003     431.0
# 1          v_X -0.044  0.088  -0.187    0.141      0.004    0.003     536.0
# 2            z  0.611  0.023   0.572    0.653      0.001    0.001     425.0
# 3            a  1.148  0.036   1.078    1.210      0.002    0.001     556.0
# 4            t  0.880  0.030   0.835    0.944      0.001    0.001     510.0
#
#    ess_tail  r_hat participant_id
# 0     650.0   1.00           1077
# 1     402.0   1.01           1077
# 2     385.0   1.01           1077
# 3     639.0   1.00           1077
# 4     538.0   1.01           1077
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.127  0.076  -0.025    0.253      0.004    0.003     431.0
# 1          v_X -0.044  0.088  -0.187    0.141      0.004    0.003     536.0
# 2            z  0.611  0.023   0.572    0.653      0.001    0.001     425.0
# 3            a  1.148  0.036   1.078    1.210      0.002    0.001     556.0
# 4            t  0.880  0.030   0.835    0.944      0.001    0.001     510.0
#
#    ess_tail  r_hat participant_id
# 0     650.0   1.00           1077
# 1     402.0   1.01           1077
# 2     385.0   1.01           1077
# 3     639.0   1.00           1077
# 4     538.0   1.01           1077
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v_Intercept, v_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:21&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 21 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# <class 'arviz.data.inference_data.InferenceData'>
# <class 'pandas.core.frame.DataFrame'>
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.455  0.091   0.273    0.607      0.004    0.003     606.0
# 1          v_X  0.069  0.094  -0.093    0.255      0.004    0.003     653.0
# 2            z  0.596  0.024   0.553    0.640      0.001    0.001     485.0
# 3            a  1.142  0.037   1.077    1.216      0.001    0.001     644.0
# 4            t  0.792  0.019   0.758    0.828      0.001    0.001     546.0
#
#    ess_tail  r_hat participant_id
# 0     375.0   1.01            843
# 1     493.0   1.00            843
# 2     634.0   1.01            843
# 3     744.0   1.00            843
# 4     495.0   1.00            843
#          param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0  v_Intercept  0.455  0.091   0.273    0.607      0.004    0.003     606.0
# 1          v_X  0.069  0.094  -0.093    0.255      0.004    0.003     653.0
# 2            z  0.596  0.024   0.553    0.640      0.001    0.001     485.0
# 3            a  1.142  0.037   1.077    1.216      0.001    0.001     644.0
# 4            t  0.792  0.019   0.758    0.828      0.001    0.001     546.0
#
#    ess_tail  r_hat participant_id
# 0     375.0   1.01            843
# 1     493.0   1.00            843
# 2     634.0   1.01            843
# 3     744.0   1.00            843
# 4     495.0   1.00            843
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v_Intercept, v_X]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:17&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 17 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# <class 'arviz.data.inference_data.InferenceData'>
# <class 'pandas.core.frame.DataFrame'>
# ...
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.291  0.087   0.139    0.452      0.004    0.003     402.0
# 1     z  0.595  0.023   0.550    0.634      0.001    0.001     395.0
# 2     a  0.950  0.030   0.894    1.006      0.001    0.001     531.0
# 3     t  0.645  0.017   0.612    0.674      0.001    0.001     431.0
#
#    ess_tail  r_hat participant_id
# 0     402.0   1.01            850
# 1     517.0   1.01            850
# 2     563.0   1.01            850
# 3     474.0   1.00            850
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:12&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 13 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.175  0.041   0.105    0.256      0.002    0.001     402.0
# 1     z  0.530  0.024   0.488    0.577      0.001    0.001     463.0
# 2     a  2.003  0.063   1.878    2.113      0.003    0.002     475.0
# 3     t  0.507  0.077   0.370    0.650      0.004    0.003     444.0
#
#    ess_tail  r_hat participant_id
# 0     335.0   1.01            856
# 1     475.0   1.00            856
# 2     494.0   1.00            856
# 3     314.0   1.00            856
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:13&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 13 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.376  0.084   0.223    0.535      0.004    0.003     457.0
# 1     z  0.562  0.021   0.524    0.605      0.001    0.001     488.0
# 2     a  0.855  0.025   0.806    0.899      0.001    0.001     369.0
# 3     t  0.638  0.011   0.617    0.658      0.001    0.000     361.0
#
#    ess_tail  r_hat participant_id
# 0     539.0   1.00            864
# 1     637.0   1.00            864
# 2     433.0   1.01            864
# 3     409.0   1.01            864
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:12&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 12 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.703  0.115   0.480    0.910      0.006    0.004     407.0
# 1     z  0.547  0.024   0.504    0.590      0.001    0.001     430.0
# 2     a  0.716  0.023   0.678    0.758      0.001    0.001     479.0
# 3     t  0.604  0.009   0.588    0.620      0.000    0.000     452.0
#
#    ess_tail  r_hat participant_id
# 0     468.0   1.01            929
# 1     581.0   1.00            929
# 2     540.0   1.01            929
# 3     458.0   1.00            929
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:13&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 14 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.512  0.054   0.417    0.621      0.003    0.002     335.0
# 1     z  0.546  0.027   0.491    0.592      0.002    0.001     277.0
# 2     a  1.812  0.071   1.677    1.938      0.003    0.002     428.0
# 3     t  1.083  0.062   0.967    1.193      0.004    0.003     285.0
#
#    ess_tail  r_hat participant_id
# 0     500.0   1.00            949
# 1     437.0   1.01            949
# 2     561.0   1.00            949
# 3     496.0   1.00            949
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:16&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 16 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.411  0.044   0.335    0.491      0.002    0.002     349.0
# 1     z  0.554  0.036   0.487    0.617      0.002    0.002     268.0
# 2     a  2.315  0.098   2.136    2.488      0.005    0.003     458.0
# 3     t  0.911  0.115   0.708    1.127      0.007    0.005     260.0
#
#    ess_tail  r_hat participant_id
# 0     363.0   1.01            967
# 1     333.0   1.02            967
# 2     505.0   1.01            967
# 3     347.0   1.01            967
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:13&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 14 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.354  0.072   0.221    0.489      0.003    0.002     582.0
# 1     z  0.516  0.023   0.474    0.561      0.001    0.001     464.0
# 2     a  1.115  0.035   1.041    1.180      0.002    0.001     481.0
# 3     t  0.669  0.027   0.624    0.726      0.001    0.001     415.0
#
#    ess_tail  r_hat participant_id
# 0     521.0    1.0           1015
# 1     429.0    1.0           1015
# 2     462.0    1.0           1015
# 3     418.0    1.0           1015
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:13&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 14 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.064  0.070  -0.061    0.198      0.003    0.002     525.0
# 1     z  0.618  0.022   0.578    0.661      0.001    0.001     517.0
# 2     a  1.145  0.035   1.082    1.216      0.001    0.001     556.0
# 3     t  0.885  0.030   0.837    0.945      0.001    0.001     469.0
#
#    ess_tail  r_hat participant_id
# 0     577.0    1.0           1077
# 1     537.0    1.0           1077
# 2     563.0    1.0           1077
# 3     467.0    1.0           1077
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:12&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 13 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.486  0.082   0.347    0.649      0.004    0.003     371.0
# 1     z  0.598  0.024   0.553    0.643      0.001    0.001     373.0
# 2     a  1.145  0.039   1.075    1.220      0.002    0.001     421.0
# 3     t  0.793  0.018   0.755    0.822      0.001    0.001     351.0
#
#    ess_tail  r_hat participant_id
# 0     436.0    1.0            843
# 1     311.0    1.0            843
# 2     435.0    1.0            843
# 3     381.0    1.0            843
# writing
# Only 300 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 3 jobs)
# NUTS: [z, a, t, v]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3900' class='' max='3900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3900/3900 00:15&lt;00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 300 draw iterations (3_000 + 900 draws total) took 16 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#   param   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 0     v  0.337  0.045   0.243    0.415      0.002    0.002     405.0
# 1     z  0.708  0.029   0.654    0.764      0.002    0.001     380.0
# 2     a  2.660  0.174   2.353    2.999      0.009    0.006     445.0
# 3     t  0.955  0.070   0.827    1.084      0.003    0.002     474.0
#
#    ess_tail  r_hat participant_id
# 0     312.0   1.00            990
# 1     412.0   1.00            990
# 2     391.0   1.01            990
# 3     473.0   1.00            990
# writing
